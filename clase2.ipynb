# %% [markdown]
# # Clase 2: Git, NumPy y Pandas
# **Python para el Análisis de Datos y la Investigación — ICM CARES**
#
# ---
#
# ## Antes de empezar
#
# Debes haber completado ya estos pasos:
#
# 1. Crear la carpeta `analisis-argo/` y copiar dentro:
#    - Este notebook → raíz del proyecto
#    - `argo_mediterraneo.csv` → dentro de `data/`
# 2. Crear el entorno virtual con uv:
#    ```bash
#    uv init
#    uv venv
#    source .venv/bin/activate   # Mac/Linux
#    .venv\Scripts\activate       # Windows
#    uv add numpy pandas matplotlib seaborn plotly jupyter
#    ```
# 3. Abrir la carpeta en VS Code y seleccionar el kernel `.venv`
#
# ---
# **Cómo usar este notebook:**
# - Ejecuta celdas con **Shift+Enter**
# - `✏️ Ejercicio` → resuélvelo tú antes de mirar la solución
# - `✅ Solución` → solo después de intentarlo
# - `🤖 Copilot tip` → prompt listo para [copilot.microsoft.com](https://copilot.microsoft.com)

# %%
# Celda de verificación inicial — ejecuta esto primero
import os

checks = {}

# Dataset
dataset_path = os.path.join('data', 'argo_mediterraneo.csv')
checks['Dataset Argo'] = os.path.exists(dataset_path)

# Paquetes
for pkg in ['numpy', 'pandas', 'matplotlib', 'seaborn', 'plotly']:
    try:
        __import__(pkg)
        checks[pkg] = True
    except ImportError:
        checks[pkg] = False

for name, ok in checks.items():
    print(f'  {"✅" if ok else "❌"}  {name}')

if not checks['Dataset Argo']:
    print(f'\n⚠️  No se encuentra el dataset. Ruta actual: {os.getcwd()}')
    print('    Asegúrate de que argo_mediterraneo.csv está en data/')

if not all(checks.values()):
    print('\n⚠️  Instala los paquetes faltantes: uv add numpy pandas matplotlib seaborn plotly jupyter')
# Out:
#   ✅  Dataset Argo
#   ✅  numpy
#   ✅  pandas
#   ✅  matplotlib
#   ✅  seaborn
#   ✅  plotly

# %% [markdown]
# ---
# # PARTE 1: Git — Control de Versiones
#
# Git se usa desde la **terminal de VS Code** (Ctrl+\` en Windows/Linux, Cmd+\` en Mac), no desde Python. Necesitarás una cuenta de GitHub.
#
# ### Flujo de hoy
#
# ```bash
# # 1. Configuración (solo la primera vez en este ordenador)
# git config --global user.email "tu@email.com"
# git config --global user.name "Tu Nombre"
#
# # 2. Inicializar el repositorio en tu carpeta de proyecto
# git init
#
# # 3. Ver el estado (todos los archivos en rojo = sin versionar)
# git status
#
# # 4. Añadir todo al staging area
# git add .
# git status   # ahora en verde
#
# # 5. Primer commit
# git commit -m "Inicio del proyecto de análisis Argo"
# git log --oneline
#
# # 6. Crear repo en github.com → copiar URL HTTPS
# git remote add origin https://github.com/tu_usuario/analisis-argo.git
# git branch -M main
# git push -u origin main
# # → Refresca GitHub. Tus archivos están en la nube.
# ```
#
# ### Archivo .gitignore
# Crea este archivo en la raíz del proyecto **antes del primer commit**:
# ```
# .venv/
# __pycache__/
# *.pyc
# .env
# .DS_Store
# ```

# %% [markdown]
# ---
# ### ✏️ Ejercicio 1 — Git: inicializar y primer push
#
# En la terminal:
# 1. Crea el `.gitignore` con el contenido de arriba
# 2. `git init` → `git add .` → `git commit -m "Inicio del proyecto de análisis Argo"`
# 3. `git log --oneline` — ¿aparece tu commit?
# 4. Crea el repositorio en github.com y haz `git push`
# 5. Refresca GitHub — ¿ves tus archivos?
#
# > 🤖 **Copilot tip:** *"Dame los pasos para subir un repositorio Git local a GitHub usando HTTPS con un token de acceso personal"*

# %% [markdown]
# ---
# # PARTE 2: NumPy — El Array Numérico

# %%
import numpy as np
print('NumPy', np.__version__)
# Out:
# NumPy 2.4.4

# %% [markdown]
# ### ¿Por qué NumPy? Velocidad

# %%
n = 1_000_000
lista = list(range(n))
print('Lista Python:')
# %timeit [x * 2.0 for x in lista]
# Out:
# Lista Python:
# 75.5 ms ± 4.19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
array = np.arange(n, dtype=float)
print('Array NumPy:')
# %timeit array * 2.0
# Out:
# Array NumPy:
# 2.08 ms ± 167 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Arrays, propiedades y operaciones vectorizadas

# %%
# Temperaturas superficiales del Mediterráneo (°C)
temps = np.array([22.1, 18.5, 25.3, 19.8, 23.7, 17.2, 24.5, 20.1])

print(f'Array:  {temps}')
print(f'Shape:  {temps.shape}  |  Dtype: {temps.dtype}  |  Ndim: {temps.ndim}')

# Operación vectorizada: sin bucle for
temps_f = (temps * 9/5) + 32
print(f'\nFahrenheit: {temps_f.round(1)}')

# Profundidades estándar de perfiles Argo
profundidades = np.linspace(0, 2000, 15)
print(f'\nProfundidades Argo (m): {profundidades}')
# Out:
# Array:  [22.1 18.5 25.3 19.8 23.7 17.2 24.5 20.1]
# Shape:  (8,)  |  Dtype: float64  |  Ndim: 1
#
# Fahrenheit: [71.8 65.3 77.5 67.6 74.7 63.  76.1 68.2]
#
# Profundidades Argo (m): [   0.          142.85714286  285.71428571  428.57142857  571.42857143
#   714.28571429  857.14285714 1000.         1142.85714286 1285.71428571
#  1428.57142857 1571.42857143 1714.28571429 1857.14285714 2000.        ]

# %%
temps = np.array([22.1, 18.5, 25.3, 19.8, 23.7])   # desde lista 
 
np.zeros(5)                  # [0. 0. 0. 0. 0.] 
np.ones(3)                   # [1. 1. 1.] 
np.linspace(0, 2000, 15)     # 15 profundidades entre 0 y 2000 m (Argo) 
np.arange(0, 100, 10)        # [0, 10, 20, ..., 90] 
 
# Datos de prueba 
rng = np.random.default_rng(42) 
temps_sim = rng.normal(20, 3, 1000)   # 1000 temperaturas simuladas

# %%
temps_sim
# Out:
# array([20.91415124, 16.88004768, 22.25135359, 22.82169415, 14.14689443,
#        16.09346148, 20.38352121, 19.05127222, 19.94959653, 17.44086822,
#        22.63819392, 22.33337581, 20.19809209, 23.38172362, 21.40252803,
#        17.42212261, 21.10625235, 17.1233522 , 22.6353509 , 19.85022227,
#        19.44541291, 17.95721137, 23.66762402, 19.53641155, 18.71501653,
#        18.94359935, 21.59692756, 21.09633219, 21.23819783, 21.29246301,
#        26.4249428 , 18.78075495, 18.46327181, 17.55868182, 21.84793827,
#        23.38691688, 19.65815763, 17.47953057, 17.52655635, 21.95177836,
#        22.22976251, 21.6294628 , 18.00347088, 20.69648397, 20.35005743,
#        20.65606579, 22.61428633, 20.67078665, 22.03674069, 20.20273721,
#        20.8673582 , 21.89386468, 15.62853254, 19.04098635, 18.58888204,
#        18.08336646, 19.17457325, 24.48482393, 17.40250665, 22.90483506,
#        14.95139069, 18.99534491, 20.4882592 , 21.75866699, 22.13367974,
#        22.38004171, 18.95382478, 18.61294462, 22.57392764, 19.42608703,
#        16.17294103, 16.60013836, 17.24164314, 21.49148223, 20.42727721,
#        22.07145606, 18.71824206, 20.47561907, 21.87677118, 19.07196038,
#        21.37032571, 18.01422218, 18.91083846, 18.85478632, 16.41248106,
#        21.46091744, 18.59179298, 20.03748236, 21.44223998, 21.33959353,
#        21.99615533, 19.70454355, 18.73010506, 19.76084537, 14.9379967 ,
#        15.65866258, 16.03190116, 17.00825952, 21.19932268, 17.28356283,
#        18.86551234, 23.89768489, 18.93120809, 22.21254671, 17.19914696,
#        19.38368733, 17.14993384, 18.98290077, 22.52092441, 14.81803873,
#        21.30327093, 20.71320681, 18.21755013, 15.66182644, 20.21638852,
#        18.41152187, 20.69802863, 20.06555644, 24.80533667, 19.28193312,
#        16.92950752, 20.5378269 , 20.65999005, 24.07756273, 22.50533374,
#        21.07061318, 24.38990867, 16.43371084, 18.0807454 , 17.22027218,
#        18.83057059, 15.86994156, 21.90545284, 19.33333191, 15.58758112,
#        16.95326276, 20.94054154, 22.5143797 , 25.99019268, 28.7415874 ,
#        21.2432283 , 17.03138564, 13.60386116, 20.80313439, 17.56117671,
#        18.75392822, 18.1637096 , 19.57762734, 23.19794069, 20.4711457 ,
#        19.52409549, 16.89303874, 14.97595117, 18.54107627, 19.83865235,
#        25.30378974, 20.39082356, 22.94821853, 18.5021132 , 16.4451687 ,
#        17.10464971, 17.82432181, 26.3854092 , 17.53583996, 22.51546761,
#        17.29121847, 22.79471904, 21.1548529 , 19.53008631, 19.87771242,
#        18.03563691, 21.3382166 , 18.63504956, 16.32318271, 16.16618728,
#        20.51776375, 24.73727377, 20.47997484, 19.64408502, 20.85747842,
#        23.91800523, 20.6581475 , 18.76721831, 23.31886613, 21.28626932,
#        24.60726798, 20.54970331, 16.3265929 , 15.8955224 , 24.9527838 ,
#        25.17099716, 19.46144236, 18.85043804, 24.38433288, 16.67886295,
#        17.31581894, 21.92998038, 18.81618463, 19.9846344 , 19.5096713 ,
#        21.01272365, 24.22244558, 20.27175472, 21.93181638, 13.8494837 ,
#        19.85384479, 17.47030919, 16.34356082, 17.3655429 , 18.99762968,
#        22.74770763, 16.02082185, 20.09189448, 18.5474917 , 19.01698072,
#        23.00827348, 21.61434631, 24.01219432, 19.53648296, 17.91217216,
#        19.32842355, 20.72749037, 20.52972008, 16.74683578, 20.27146934,
#        20.68468499, 27.55242211, 25.63053383, 17.44026995, 19.13784992,
#        15.60967399, 18.22787896, 20.94681501, 23.61756086, 17.81274849,
#        18.03756068, 13.55813291, 19.51200224, 16.81275676, 18.41168172,
#        17.36941767, 19.71721234, 14.72681483, 15.59886426, 26.38774134,
#        16.13773226, 16.70964326, 25.51074058, 28.71520151, 16.48530011,
#        18.89525313, 21.02466665, 25.18609293, 17.03942876, 19.26416646,
#        22.33201273, 21.30429822, 18.87153179, 19.59853111, 15.87531257,
#        19.28547877, 19.20083753, 20.69650967, 18.33401834, 21.41461557,
#        23.03814745, 20.46628798, 21.05526923, 20.15946604, 20.00025318,
#        17.8353259 , 20.94948279, 19.7081402 , 26.27950493, 24.72006471,
#        21.15753966, 17.71082837, 16.66276558, 23.57342886, 20.78824768,
#        21.44043021, 14.76624204, 22.78231544, 21.36326101, 16.66870795,
#        18.58542558, 20.79115161, 20.1574004 , 19.12348644, 19.6895352 ,
#        19.24406787, 20.45768754, 24.41447592, 12.30002468, 19.28944921,
#        20.52953726, 20.88798197, 18.88425626, 14.72983465, 20.98398645,
#        25.18205064, 15.39841579, 22.59148404, 19.01442433, 19.81602696,
#        16.84130447, 18.99663148, 23.90013378, 21.74796573, 25.19693482,
#        23.53223567, 21.31726004, 25.23180358, 21.31697948, 22.48396453,
#        19.11028714, 20.19963745, 17.90772853, 22.9687518 , 16.46508913,
#        22.34705103, 19.42804683, 23.51374128, 22.25260697, 25.46193847,
#        22.19232407, 15.28387923, 19.79914048, 16.48397842, 18.44516047,
#        24.5336853 , 21.91260143, 17.90320871, 16.9588479 , 20.09834628,
#        16.35031955, 17.98657917, 20.93602841, 23.46593611, 21.82628442,
#        13.12613147, 20.91310019, 20.21610072, 21.24167086, 24.84862904,
#        13.81028517, 18.22668972, 21.77271897, 15.2552168 , 24.42784714,
#        21.10506984, 22.53975196, 18.28716902, 22.44129107, 23.20541467,
#        20.69863406, 20.70320268, 20.81102972, 17.40996421, 19.55741396,
#        19.5424324 , 21.15018159, 22.99947274, 16.82439175, 19.62497291,
#        24.44436664, 17.76923531, 17.53324995, 20.60691858, 22.53315557,
#        20.03427817, 23.98688177, 22.57038195, 22.5254602 , 21.6623495 ,
#        26.9829593 , 19.38451493, 13.98943312, 24.81276308, 18.62690171,
#        20.32364133, 23.92865205, 15.19322138, 16.24505836, 15.19616619,
#        17.61759113, 21.31890982, 21.57256353, 20.82882254, 15.76170235,
#        13.06968969, 20.16306076, 18.5846719 , 21.37815732, 22.10586088,
#        20.4147243 , 22.28039926, 20.68763412, 21.59019412, 17.88598021,
#        19.46116576, 20.59032829, 22.46158543, 18.81877648, 21.56350177,
#        19.20248362, 19.6473735 , 22.48855713, 14.02081889, 16.11058302,
#        15.55344381, 12.99915164, 17.96520668, 22.2483017 , 19.1453478 ,
#        20.59337025, 23.26765249, 23.9830584 , 19.7925862 , 24.06075767,
#        20.27637998, 17.48780533, 18.21679894, 15.55839046, 17.33559844,
#        18.92594994, 22.41075506, 25.16230949, 15.85345545, 21.1784824 ,
#        16.87836818, 21.42409127, 19.60674005, 14.50728252, 22.78489097,
#        18.18499786, 18.39829928, 16.79074277, 18.03715017, 21.28367132,
#        19.43226698, 20.98598601, 21.08576556, 23.96198497, 18.97164155,
#        15.56942655, 23.20166725, 19.00553548, 23.34377733, 21.15013134,
#        19.60658741, 21.04632768, 25.85303768, 26.23094159, 20.20814341,
#        20.48057178, 23.22872047, 17.4630169 , 20.99921112, 19.92241146,
#        20.94172463, 17.49989358, 15.23129752, 13.78104969, 16.64784766,
#        18.62397415, 19.12042524, 25.81169349, 23.31798011, 17.11372665,
#        21.04312536, 18.77876529, 19.14690849, 20.55597695, 21.85751335,
#        18.98222455, 23.1915546 , 16.57418532, 20.01901719, 27.79302118,
#        20.66923923, 24.29964352, 20.27456053, 21.74233129, 19.82965042,
#        19.48877726, 17.66155281, 21.29090408, 17.44538843, 21.99675571,
#        23.25586101, 21.09959422, 19.1412538 , 21.36189674, 19.07398083,
#        22.80664138, 14.50578175, 18.9931779 , 14.02756401, 15.51481751,
#        24.09158669, 22.68555495, 17.8415593 , 15.49248963, 11.10641349,
#        18.36951348, 27.26124504, 21.30465281, 18.32128314, 21.39524063,
#        15.31712494, 19.10802991, 20.29843242, 19.74169804, 22.37241837,
#        21.03393568, 22.00497805, 17.93488315, 22.69344623, 24.88681084,
#        17.08955144, 17.33691303, 24.00735301, 19.42596804, 24.21146418,
#        18.67239286, 24.36513673, 20.39445745, 20.77468647, 24.69415407,
#        18.91468857, 17.17663371, 18.65430738, 21.35700185, 15.30272278,
#        21.91241271, 18.38368605, 23.44343798, 12.81721909, 17.64030267,
#        14.94059555, 17.5213116 , 20.7429977 , 19.46232012, 19.23986729,
#        19.52244539, 20.61016472, 16.97439187, 22.12054892, 21.98799791,
#        21.15511381, 21.66960033, 20.889254  , 26.10521991, 19.73871749,
#        19.07875034, 17.73941726, 16.90321199, 16.26658464, 17.33360806,
#        19.78795886, 21.00288539, 20.15342618, 17.70339417, 22.70055369,
#        22.21823802, 19.52105508, 18.04125157, 21.64528376, 20.56392076,
#        15.65561822, 19.79605923, 20.78610744, 17.30091564, 20.56953018,
#        15.63553254, 24.0085583 , 23.74384996, 19.242448  , 21.09036301,
#        12.7702341 , 16.53095702, 19.11866324, 16.78360094, 22.14318945,
#        25.99188959, 16.47015584, 17.48760979, 20.7063451 , 24.83334845,
#        16.33287706, 20.74710837, 25.46389655, 15.04472256, 16.15679238,
#        18.72918018, 18.43823476, 22.43780386, 20.72497916, 14.67511382,
#        21.54623121, 18.26738334, 23.82334165, 18.11723739, 18.09015415,
#        21.62339483, 22.28877945, 21.34429809, 14.94320805, 21.61410332,
#        16.89707584, 20.70582833, 15.72879669, 21.33896644, 17.58020329,
#        16.15209605, 22.14146041, 20.72493357, 18.1580696 , 24.35353655,
#        18.67804274, 20.09632302, 20.80674034, 18.1410022 , 21.41340888,
#        18.39964296, 18.76508503, 24.08792792, 16.87824184, 12.76165901,
#        24.83281099, 27.64798386, 18.7841922 , 14.18948588, 19.06854807,
#        19.14133115, 19.43022848, 16.65983587, 21.73868343, 21.57352213,
#        15.51678314, 22.0975902 , 26.15805495, 20.515881  , 18.98802451,
#        19.57399036, 21.8457703 , 14.80798518, 20.49317211, 18.82860815,
#        25.54347504, 19.4774818 , 25.00366283, 16.68877791, 21.7617775 ,
#        20.95820079, 17.39285826, 20.53218834, 23.63755651, 19.02862489,
#        14.92411205, 19.94731152, 17.29273072, 18.97297718, 19.75523669,
#        14.88304335, 15.15302498, 21.44620051, 18.43184391, 12.30576697,
#        22.35453211, 20.81710927, 17.85837553, 16.04950937, 22.50742369,
#        21.04805187, 27.14780685, 21.2605658 , 21.16310942, 19.49921621,
#        22.4503276 , 21.8752556 , 23.75517503, 18.43603124, 18.69377758,
#        18.56269049, 22.37240516, 24.49512332, 18.62347852, 18.72567882,
#        20.94223167, 19.2627155 , 22.85616096, 13.24466813, 17.51988486,
#        17.652751  , 13.03893196, 17.10908467, 17.25453165, 19.39668604,
#        23.33889767, 19.26481805, 16.90755884, 19.82913638, 23.14752086,
#        17.07212355, 17.26827535, 21.67564688, 19.33539165, 21.94245407,
#        19.95905962, 22.10499094, 16.89476566, 19.96374605, 19.36792996,
#        16.35232723, 15.30956616, 22.05724711, 18.94714285, 16.93315916,
#        19.71146319, 23.38405657, 13.15778646, 15.51008393, 17.23134067,
#        24.3835366 , 20.84776095, 22.30195172, 16.57951724, 16.64139237,
#        21.34344115, 20.17482299, 21.64621646, 19.43698703, 20.83443118,
#        20.47435725, 22.33330217, 22.42102485, 15.14038402, 13.25819433,
#        23.00523619, 23.56317528, 16.93813094, 14.42049378, 20.29710446,
#        22.79251468, 25.39278357, 21.54889272, 18.88484991, 17.32060814,
#        20.03435388, 19.10220589, 16.95479628, 26.14626695, 25.35550521,
#        23.40814605, 17.23744881, 22.56505797, 21.91887923, 21.32763687,
#        23.7489958 , 21.90611343, 22.22004271, 21.91071885, 21.02237422,
#        14.64916661, 20.25086323, 18.33142412, 16.16047713, 25.04544986,
#        25.18698602, 24.0776618 , 20.76564025, 24.05187536, 20.03615954,
#        20.60839183, 16.71958589, 21.19097391, 20.18115779, 16.09204365,
#        19.84640866, 19.76081131, 25.3926835 , 22.68263999, 20.03433632,
#        20.74636193, 20.13263713, 19.39125805, 16.75271841, 19.54684437,
#        17.76170523, 16.24905338, 21.53366544, 21.17379398, 14.63987747,
#        19.63194609, 22.98710416, 23.17767122, 23.07751053, 20.11673962,
#        17.46486402, 16.74890352, 21.03381471, 21.1378401 , 23.86199333,
#        23.29993895, 19.60331403, 16.26738236, 19.04268021, 20.65169358,
#        19.39375026, 18.26631768, 20.75865444, 18.48812678, 18.11580175,
#        20.9343585 , 18.79402226, 20.73231317, 20.81961207, 16.581713  ,
#        18.55627663, 24.31333082, 16.51376146, 13.65003665, 14.41446454,
#        20.08732984, 20.09275183, 19.64716743, 23.64256949, 11.9814967 ,
#        21.18780162, 24.68431461, 16.61665771, 18.86058046, 17.74132425,
#        17.31696186, 19.02121398, 24.28245585, 25.51216003, 18.99218232,
#        25.71518064, 20.10672943, 25.26107308, 19.72010405, 20.39317348,
#        21.09642342, 29.53656104, 22.55385672, 17.87820641, 22.90699361,
#        18.91450239, 18.53074945, 22.72580408, 20.09325676, 20.83572774,
#        20.04195567, 21.00974938, 21.27489769, 14.1890992 , 21.99971801,
#        17.05394174, 15.67310259, 19.82476627, 20.25194301, 17.91948151,
#        22.49309557, 15.9734745 , 18.77916875, 18.2453776 , 19.86023819,
#        20.83659285, 16.97632115, 22.17284803, 20.18900711, 14.32416124,
#        14.12422568, 19.96304212, 19.33709805, 19.68973966, 19.91605263,
#        20.67667952, 22.84294883, 16.6666853 , 16.48408522, 16.72002843,
#        20.86675   , 23.73484214, 18.70598169, 12.49490047, 14.88802141,
#        17.50088983, 18.32681334, 18.77483412, 20.11574337, 19.06476101,
#        23.14801883, 17.97194808, 17.41304612, 21.43662662, 15.39307379,
#        21.16907512, 20.30765955, 19.55767253, 24.76482832, 18.13337766,
#        26.18089451, 19.32370565, 16.16895067, 20.20975874, 16.7712644 ,
#        17.74473246, 21.1910999 , 21.66674627, 18.1334969 , 22.96221544,
#        23.47252327, 24.30890527, 21.58824022, 24.09028614, 14.35760472,
#        19.04628035, 17.39898423, 20.35767758, 18.28565234, 19.50152647,
#        25.64652464, 19.49084061, 21.24137695, 19.30319201, 20.22713986,
#        20.01805004, 21.3449722 , 23.49592261, 24.94218199, 20.92886025,
#        21.76864066, 16.54740647, 19.73636977, 22.82086839, 22.59790592,
#        20.6348292 , 22.65918188, 21.47230013, 23.60091877, 20.86807747,
#        18.93290505, 21.00752377, 11.20821687, 21.14865721,  9.05476152,
#        14.82960978, 21.3553058 , 21.43258801, 16.51271366, 17.86369387,
#        24.11162297, 18.54790961, 26.72876094, 19.99424044, 21.22410853,
#        24.8506232 , 20.39308135, 16.99296806, 19.67081764, 19.89316779,
#        15.90577504, 19.23250379, 17.77342372, 22.77307327, 20.10383562,
#        19.15161275, 19.68145421, 20.66936606, 21.8504426 , 17.00086331,
#        16.8752371 , 23.31403765, 18.76298938, 15.74947372, 21.33143813,
#        21.39010942, 15.40785423, 20.68844515, 22.20674928, 21.12315936,
#        21.89594445, 15.78719271, 20.99312046, 19.09214072, 18.55162952,
#        22.61166683, 24.43782353, 25.38311016, 23.94442361, 19.67079746,
#        21.05816049, 22.30046862, 20.36353385, 20.39229256, 22.4712594 ])

# %% [markdown]
# ### Máscaras booleanas — el mismo mecanismo que Pandas

# %%
# La condición genera un array de True/False
mask = temps > 22
print(f'Máscara (>22°C):       {mask}')
print(f'Temperaturas cálidas:  {temps[mask]}')

# Forma abreviada
print(f'Forma abreviada:       {temps[temps > 22]}')

# Condición combinada: & para AND, | para OR (igual que en Pandas)
print(f'Entre 19 y 23°C:       {temps[(temps >= 19) & (temps <= 23)]}')
# Out:
# Máscara (>22°C):       [ True False  True False  True]
# Temperaturas cálidas:  [22.1 25.3 23.7]
# Forma abreviada:       [22.1 25.3 23.7]
# Entre 19 y 23°C:       [22.1 19.8]

# %% [markdown]
# ### Estadísticas y NaN

# %%
print(f'Media:           {np.mean(temps):.2f} °C')
print(f'Std:             {np.std(temps):.2f} °C')
print(f'Rango:           {np.min(temps):.1f} – {np.max(temps):.1f} °C')
print(f'Percentil 25/75: {np.percentile(temps, 25):.1f} / {np.percentile(temps, 75):.1f} °C')
# Out:
# Media:           21.88 °C
# Std:             2.48 °C
# Rango:           18.5 – 25.3 °C
# Percentil 25/75: 19.8 / 23.7 °C

# %%
# NaN: habitual en datos Argo (sensor caído, boya que no llegó a esa profundidad)
datos = np.array([22.1, np.nan, 25.3, np.nan, 23.7, 17.2])

print(f'Posiciones NaN:    {np.isnan(datos)}')
print(f'np.mean (con NaN): {np.mean(datos)}')           # → nan
print(f'np.nanmean:        {np.nanmean(datos):.2f}')    # correcto
print(f'Valores válidos:   {np.sum(~np.isnan(datos))} de {len(datos)}')
# Out:
# Posiciones NaN:    [False  True False  True False False]
# np.mean (con NaN): nan
# np.nanmean:        22.08
# Valores válidos:   4 de 6

# %%
~np.isnan(datos)
    #and -> &
    #or -> |
    #not -> ~
# Out:
# array([ True, False,  True, False,  True,  True])

# %% [markdown]
# ---
# ### ✏️ Ejercicio 2 — NumPy: estadísticas de salinidad

# %%
sal = np.array([38.2, 37.8, np.nan, 38.9, 37.5, np.nan, 38.4, 39.1, np.nan, 37.9, 38.7])

# TU CÓDIGO:
# a) ¿Cuántos NaN hay?
print(f'a) NaN: {np.sum(np.isnan(sal)) }')
# b) Media, máximo y percentil 90 ignorando NaN
print(f'b) Media: {np.nanmean(sal)}')
print(f'b) Máx: {np.nanmax(sal)}')
print(f'b) P90: {np.nanpercentile(sal,90)} PSU')

print(f'b) Media: {np.nanmean(sal):.3f} | Máx: {np.nanmax(sal):.3f} | P90: {np.nanpercentile(sal, 90):.3f} PSU')
# c) Valores con salinidad > 38.5 PSU
sal38 = sal > 38.5
print(f'c) > 38.5 PSU {sal[sal38]}')
# d) ¿Cuántos valores son válidos?
print(f'd) Válidos: {np.sum(~np.isnan(sal))} de {len(sal)}')
# Out:
# a) NaN: 3
# b) Media: 38.3125
# b) Máx: 39.1
# b) P90: 38.96 PSU
# b) Media: 38.312 | Máx: 39.100 | P90: 38.960 PSU
# c) > 38.5 PSU [38.9 39.1 38.7]
# d) Válidos: 8 de 11

# %% [markdown]
# > 🤖 **Copilot tip:** *"Tengo un array NumPy con NaN. ¿Cómo cuento los NaN, calculo estadísticas ignorándolos y filtro por un umbral?"*

# %%
# ✅ SOLUCIÓN
print(f'a) NaN: {np.sum(np.isnan(sal))}')
print(f'b) Media: {np.nanmean(sal):.3f} | Máx: {np.nanmax(sal):.3f} | P90: {np.nanpercentile(sal, 90):.3f} PSU')
print(f'c) > 38.5 PSU: {sal[sal > 38.5]}')
print(f'd) Válidos: {np.sum(~np.isnan(sal))} de {len(sal)}')
# Out:
# a) NaN: 3
# b) Media: 38.312 | Máx: 39.100 | P90: 38.960 PSU
# c) > 38.5 PSU: [38.9 39.1 38.7]
# d) Válidos: 8 de 11

# %% [markdown]
# ---
# # PARTE 3: Pandas — Dataset Argo Real

# %%
import pandas as pd
import os
print('Pandas', pd.__version__)
# Out:
# Pandas 3.0.2

# %% [markdown]
# ### 3.1 Cargar y explorar el dataset

# %%
df = pd.read_csv(os.path.join('data', 'argo_mediterraneo.csv'))
print(f'Cargado: {df.shape[0]:,} mediciones, {df.shape[1]} variables')
df.head(10)
# Out:
# Cargado: 9,000 mediciones, 9 variables
#    float_id                 date  latitude  longitude  depth  pressure  \
# 0   6903291  2021-01-01T03:15:39   36.2805    24.3338   99.9     102.4
# 1   6902874  2021-01-01T05:08:30   34.6341    31.2164  363.2     372.3
# 2   6902874  2021-01-01T05:08:30   34.6341    31.2164  390.0     399.8
# 3   6902872  2021-01-01T05:08:30   36.1199    20.5688   47.6      48.8
# 4   6902872  2021-01-01T05:08:30   36.1199    20.5688  424.6     435.2
# 5   6902872  2021-01-01T05:08:30   36.1199    20.5688  265.5     272.1
# 6   6901280  2021-01-01T05:51:30   39.9338     2.2640    7.7       7.9
# 7   6902899  2021-01-01T11:35:00   42.3766     6.4397  240.3     246.3
# 8   6903250  2021-01-01T11:44:00   42.1255    18.1044  239.1     245.1
# 9   6903250  2021-01-01T11:44:00   42.1255    18.1044  137.6     141.0
#
#    temperature  salinity                  basin
# 0       17.548    39.323  Eastern Mediterranean
# 1       14.960    38.608  Eastern Mediterranean
# 2       14.800    38.580  Eastern Mediterranean
# 3       18.518    39.269  Eastern Mediterranean
# 4       15.421    39.149  Eastern Mediterranean
# 5       15.653    39.136  Eastern Mediterranean
# 6       14.699    38.069  Western Mediterranean
# 7       13.874    38.641  Western Mediterranean
# 8       14.629    38.953               Adriatic
# 9       15.004    39.001               Adriatic

# %%
df.info()
df["temperature"] #para ver la info de la columna
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   float_id     9000 non-null   int64
#  1   date         9000 non-null   str
#  2   latitude     9000 non-null   float64
#  3   longitude    9000 non-null   float64
#  4   depth        9000 non-null   float64
#  5   pressure     9000 non-null   float64
#  6   temperature  9000 non-null   float64
#  7   salinity     9000 non-null   float64
#  8   basin        9000 non-null   str
# dtypes: float64(6), int64(1), str(2)
# memory usage: 632.9 KB

# %%
df.describe().round(3)
# Out:
#           float_id  latitude  longitude     depth  pressure  temperature  \
# count     9000.000  9000.000   9000.000  9000.000  9000.000     9000.000
# mean   6584348.881    38.481     13.711   197.798   202.743       14.819
# std     976110.841     3.581     11.610   135.135   138.514        2.695
# min    1902575.000    31.305     -5.829     0.500     0.500        7.473
# 25%    6902803.000    35.556      4.469    77.300    79.200       13.713
# 50%    6903015.000    38.580      9.149   179.950   184.450       14.384
# 75%    6903245.000    41.407     25.729   307.150   314.850       15.751
# max    7901066.000    46.998     36.990   487.500   499.700       29.648
#
#        salinity
# count  9000.000
# mean     36.451
# std       6.819
# min       0.000
# 25%      38.218
# 50%      38.603
# 75%      38.957
# max      39.880

# %%
print('Mediciones por cuenca:')
print(df['basin'].value_counts())
print(f'\nBoyas únicas: {df["float_id"].nunique()}')
print(f'Período: {df["date"].min()[:10]} → {df["date"].max()[:10]}')
# Out:
# Mediciones por cuenca:
# basin
# Western Mediterranean    5351
# Eastern Mediterranean    2755
# Tyrrhenian                359
# Adriatic                  299
# Ligurian                  236
# Name: count, dtype: int64
#
# Boyas únicas: 174
# Período: 2021-01-01 → 2023-12-30

# %% [markdown]
# ### 3.2 Selección y filtrado

# %%
# Filtrado simple
df_calido = df[df['temperature'] > 22] #esto es una "mascara" -> es una serie pk estamos con panda, aunque sea parecido a una array
print(f'Mediciones > 22°C: {len(df_calido):,} ({len(df_calido)/len(df)*100:.1f}%)')

# Condición múltiple — OJO: & con paréntesis, nunca and
df_sc = df[(df['temperature'] > 22) & (df['depth'] < 50)]
print(f'Superficial (< 50m) Y cálido (> 22°C): {len(df_sc):,}')
# Out:
# Mediciones > 22°C: 238 (2.6%)
# Superficial (< 50m) Y cálido (> 22°C): 232

# %%
# loc vs iloc
print('loc — por nombre:')
print(df.loc[0:3, 'temperature':'depth'])

print('\niloc — por posición:')
print(df.iloc[0:4, 4:8])
# Out:
# loc — por nombre:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]
#
# iloc — por posición:
#    depth  pressure  temperature  salinity
# 0   99.9     102.4       17.548    39.323
# 1  363.2     372.3       14.960    38.608
# 2  390.0     399.8       14.800    38.580
# 3   47.6      48.8       18.518    39.269

# %% [markdown]
# ### 3.3 Valores nulos

# %%
nulos = df.isnull().sum()
pct = (nulos / len(df) * 100).round(1)
print(pd.DataFrame({'Nulos': nulos, '%': pct})[nulos > 0])
# Out:
# Empty DataFrame
# Columns: [Nulos, %]
# Index: []

# %%
df_limpio = df.dropna(subset=['temperature', 'salinity']).copy()
print(f'Original: {len(df):,}  →  Limpio: {len(df_limpio):,}  (eliminadas: {len(df)-len(df_limpio):,})')
print('→ Los NaN suelen indicar que la boya no llegó a esa profundidad.')
# Out:
# Original: 9,000  →  Limpio: 9,000  (eliminadas: 0)
# → Los NaN suelen indicar que la boya no llegó a esa profundidad.

# %% [markdown]
# ---
# ### ✏️ Ejercicio 3 — Pandas: explorar el dataset

# %%
# Con df (original, sin limpiar):
# a) Total de mediciones
# b) Columnas con nulos y su porcentaje
# c) Temperatura máxima y mínima
# d) Número de boyas únicas
# e) Cuenca con más mediciones

# TU CÓDIGO:

# %% [markdown]
# > 🤖 **Copilot tip:** *"Tengo un DataFrame pandas. ¿Cómo cuento valores únicos en una columna y veo el porcentaje de nulos por columna?"*

# %%
# ✅ SOLUCIÓN
print(f'a) Total: {len(df):,}')
nulos = df.isnull().sum()
print('\nb) Nulos:')
print(pd.DataFrame({'n': nulos, '%': (nulos/len(df)*100).round(1)})[nulos > 0])
print(f'\nc) Temp max/min: {df["temperature"].max():.2f} / {df["temperature"].min():.2f} °C')
print(f'\nd) Boyas únicas: {df["float_id"].nunique()}')
print(f'\ne) Cuenca con más mediciones: {df["basin"].value_counts().index[0]}')
# Out:
# a) Total: 9,000
#
# b) Nulos:
# Empty DataFrame
# Columns: [n, %]
# Index: []
#
# c) Temp max/min: 29.65 / 7.47 °C
#
# d) Boyas únicas: 174
#
# e) Cuenca con más mediciones: Western Mediterranean

# %% [markdown]
# ---
# ### ✏️ Ejercicio 4 — Pandas: mediciones más cálidas en superficie

# %%
# Las 10 mediciones superficiales más cálidas del Mediterráneo occidental
# Superficial: depth < 10 m
# Cuenca: basin == 'Western Mediterranean'
# Mostrar solo: temperature, salinity, depth, basin, date

# TU CÓDIGO:

# %% [markdown]
# > 🤖 **Copilot tip:** *"DataFrame pandas con columnas temperature, depth, basin. ¿Cómo selecciono las 10 filas con mayor temperatura donde depth < 10 y basin es 'Western Mediterranean'?"*

# %%
# ✅ SOLUCIÓN
(
    df_limpio[(df_limpio['depth'] < 10) & (df_limpio['basin'] == 'Western Mediterranean')]
    .nlargest(10, 'temperature')
    [['temperature', 'salinity', 'depth', 'basin', 'date']]
)
# Out:
#       temperature  salinity  depth                  basin                 date
# 7777       29.648    36.912    3.0  Western Mediterranean  2023-07-18T15:40:00
# 2145       29.491    38.453    2.9  Western Mediterranean  2021-08-20T10:03:30
# 2237       28.306    39.587    5.5  Western Mediterranean  2021-08-31T09:29:00
# 5231       28.097    37.326    4.7  Western Mediterranean  2022-08-25T11:48:30
# 2200       28.093    37.717    2.3  Western Mediterranean  2021-08-26T10:34:00
# 1990       27.961    38.629    5.0  Western Mediterranean  2021-07-31T07:44:30
# 5261       27.751     5.849    8.8  Western Mediterranean  2022-08-29T19:59:30
# 8001       27.465    37.301    2.8  Western Mediterranean  2023-08-16T06:09:30
# 8080       27.139    38.305    3.8  Western Mediterranean  2023-08-26T02:58:30
# 5273       27.086    37.542    5.8  Western Mediterranean  2022-09-01T05:55:30

# %% [markdown]
# ---
# # PARTE 4: Pandas II — Transformación

# %%
# Fechas, nuevas columnas y apply()
df_limpio['date']  = pd.to_datetime(df_limpio['date'])
df_limpio['month'] = df_limpio['date'].dt.month
df_limpio['year']  = df_limpio['date'].dt.year
df_limpio['temp_f']     = df_limpio['temperature'] * 9/5 + 32
df_limpio['is_surface'] = df_limpio['depth'].apply(lambda d: d < 50)

def clasificar_profundidad(d):
    """Clasifica la profundidad según zonas oceánicas estándar."""
    if d < 10:     return 'superficie'
    elif d < 200:  return 'epipelágico'
    elif d < 1000: return 'mesopelágico'
    else:          return 'batipelágico'

df_limpio['zona'] = df_limpio['depth'].apply(clasificar_profundidad)

print('Distribución por zona:')
print(df_limpio['zona'].value_counts())
# Out:
# Distribución por zona:
# zona
# epipelágico     4658
# mesopelágico    4082
# superficie       260
# Name: count, dtype: int64

# %%
# Agrupaciones: adelanto de lo que haremos en Clase 3
df_limpio.groupby('basin').agg(
    media_temp   = ('temperature', 'mean'),
    std_temp     = ('temperature', 'std'),
    media_sal    = ('salinity',    'mean'),
    n_mediciones = ('temperature', 'count')
).round(3).sort_values('media_temp', ascending=False)
# Out:
#                        media_temp  std_temp  media_sal  n_mediciones
# basin
# Adriatic                   15.232     1.891     38.869           299
# Tyrrhenian                 15.021     1.985     38.232           359
# Eastern Mediterranean      14.968     3.574     34.523          2755
# Western Mediterranean      14.738     2.251     37.097          5351
# Ligurian                   14.105     1.159     38.534           236

# %%
# Guardar el dataset limpio
out = os.path.join('data', 'argo_limpio.csv')
df_limpio.to_csv(out, index=False)
print(f'Guardado: {out}  ({len(df_limpio):,} filas)')
# Out:
# Guardado: data\argo_limpio.csv  (9,000 filas)

# %% [markdown]
# ---
# ### ✏️ Ejercicio 5 — Pandas: resumen por cuencas

# %%
# Calcula para cada cuenca:
#   temperatura media, std temperatura, salinidad media, std salinidad, n mediciones
# Ordena por temperatura media descendente

# TU CÓDIGO:

# %% [markdown]
# > 🤖 **Copilot tip:** *"¿Cómo uso groupby en pandas para calcular varias estadísticas a la vez con nombres de columna personalizados?"*

# %%
# ✅ SOLUCIÓN
df_limpio.groupby('basin').agg(
    media_temp   = ('temperature', 'mean'),
    std_temp     = ('temperature', 'std'),
    media_sal    = ('salinity',    'mean'),
    std_sal      = ('salinity',    'std'),
    n_mediciones = ('temperature', 'count')
).round(3).sort_values('media_temp', ascending=False)
# Out:
#                        media_temp  std_temp  media_sal  std_sal  n_mediciones
# basin
# Adriatic                   15.232     1.891     38.869    0.387           299
# Tyrrhenian                 15.021     1.985     38.232    2.979           359
# Eastern Mediterranean      14.968     3.574     34.523    8.666          2755
# Western Mediterranean      14.738     2.251     37.097    5.991          5351
# Ligurian                   14.105     1.159     38.534    0.204           236

# %% [markdown]
# ---
# # PARTE 5: Script con Copilot + Git Push ⭐
#
# ### ✏️ Ejercicio 6 — Generar `analisis_argo.py` y hacer push
#
# **Pasos:**
# 1. Abre [copilot.microsoft.com](https://copilot.microsoft.com)
# 2. Envía el prompt de abajo
# 3. Pega el código en un nuevo archivo `analisis_argo.py` en VS Code
# 4. Revisa el código — ¿hace lo que pediste? ¿hay errores evidentes?
# 5. Ejecuta desde la terminal: `python analisis_argo.py`
# 6. Si hay errores → pégalos en Copilot: *"Mi script da este error: [error]. ¿Cómo lo soluciono?"*
# 7. Cuando funcione, sube a GitHub:
#    ```bash
#    git add analisis_argo.py data/argo_limpio.csv
#    git commit -m "Añadir script de análisis Pandas y dataset limpio"
#    git push
#    ```
# 8. Refresca tu repositorio en github.com — tu análisis está en la nube 🎉

# %% [markdown]
# > 🤖 **Prompt para Copilot:**
# >
# > *"Escribe un script Python llamado analisis_argo.py que use Pandas para:
# > 1. Cargar el archivo data/argo_mediterraneo.csv
# > 2. Mostrar el número de filas, columnas y un resumen de nulos por columna
# > 3. Eliminar las filas donde temperature o salinity sean NaN
# > 4. Crear una columna is_surface con valor True si depth < 50 metros
# > 5. Calcular e imprimir la temperatura media y la salinidad media por cuenca
# > 6. Guardar el DataFrame limpio como data/argo_limpio.csv
# >
# > El script debe tener comentarios en castellano, funciones con docstrings,
# > y el bloque if __name__ == '__main__' al final."*

# %% [markdown]
# ---
# ## Resumen de la Clase 2
#
# | Tema | Lo más importante |
# |------|-------------------|
# | **uv** | `uv init` + `uv venv` + `uv add`. Cada proyecto tiene su propio entorno reproducible. |
# | **Git** | `init` → `add` → `commit` → `push`. Cada commit es un punto de restauración. |
# | **NumPy** | Operaciones vectorizadas sin bucles. `np.nanmean()` para datos con NaN. Las máscaras booleanas son el mismo mecanismo que Pandas. |
# | **Pandas** | `info()` + `describe()` siempre al cargar. `isnull().sum()` para nulos. `&`/`|` con paréntesis en condiciones múltiples. |
#
# ### En la Clase 3:
# - Pandas avanzado: groupby complejo, pivot tables, merge
# - Visualización con Matplotlib, Seaborn y Plotly
# - Mapa interactivo de boyas Argo en el Mediterráneo
# - Buenas prácticas: PEP 8, docstrings, logging
# - Taller integrador: análisis completo de principio a fin
